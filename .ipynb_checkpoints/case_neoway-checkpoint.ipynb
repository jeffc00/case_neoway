# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder

# %%
conn_df = pd.read_csv('conexoes_espec.csv', sep=';')

# %%
conn_df.head(10)
# Out:
#    V1  V2      grau       proximidade  prob_V1_V2
# 0   1   2  trabalho  visita_frequente    0.589462
# 1   1   3  trabalho       visita_rara    0.708465
# 2   2   4  trabalho     visita_casual         NaN
# 3   2   5  trabalho       visita_rara    0.638842
# 4   3   6    amigos        mora_junto         NaN
# 5   3   7   familia     visita_casual    0.709608
# 6   4   8   familia        mora_junto         NaN
# 7   4   9    amigos     visita_casual    0.465209
# 8   5  10  trabalho  visita_frequente    0.658706
# 9   5  11  trabalho     visita_casual         NaN

# %%
conn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999999 entries, 0 to 999998
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   V1           999999 non-null  int64
#  1   V2           999999 non-null  int64
#  2   grau         999999 non-null  object
#  3   proximidade  999999 non-null  object
#  4   prob_V1_V2   499999 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 38.1+ MB

# %%
conn_df.describe(include='all').T
# Out:
#                 count unique          top    freq       mean            std  \
# V1           999999.0    NaN          NaN     NaN  250000.25  144337.495129
# V2           999999.0    NaN          NaN     NaN   500001.0  288674.990255
# grau           999999      3     trabalho  333548        NaN            NaN
# proximidade    999999      4  visita_rara  400238        NaN            NaN
# prob_V1_V2   499999.0    NaN          NaN     NaN   0.485162       0.173963
#
#                   min       25%       50%       75%        max
# V1                1.0  125000.5  250000.0  375000.0   500000.0
# V2                2.0  250001.5  500001.0  750000.5  1000000.0
# grau              NaN       NaN       NaN       NaN        NaN
# proximidade       NaN       NaN       NaN       NaN        NaN
# prob_V1_V2   0.074462  0.351677  0.486413   0.61821   0.942245

# %%
conn_df['grau'].unique()
# Out:
# array(['trabalho', 'amigos', 'familia'], dtype=object)

# %%
conn_df['proximidade'].unique()
# Out:
# array(['visita_frequente', 'visita_rara', 'visita_casual', 'mora_junto'],
#       dtype=object)

# %%
# rev_conn_df = conn_df[['V2', 'V1', 'grau', 'proximidade']].copy(deep=True).rename(columns={'V1': 'V2', 'V2': 'V1'})
# rev_conn_df['prob_V1_V2'] = np.nan

# conn_df['is_collected'] = True
# rev_conn_df['is_collected'] = False

# conn_df = conn_df.append(rev_conn_df, ignore_index=True)

# %%
conn_df
# Out:
#             V1       V2      grau       proximidade  prob_V1_V2
# 0            1        2  trabalho  visita_frequente    0.589462
# 1            1        3  trabalho       visita_rara    0.708465
# 2            2        4  trabalho     visita_casual         NaN
# 3            2        5  trabalho       visita_rara    0.638842
# 4            3        6    amigos        mora_junto         NaN
# ...        ...      ...       ...               ...         ...
# 999994  499998   999996  trabalho       visita_rara         NaN
# 999995  499998   999997  trabalho       visita_rara         NaN
# 999996  499999   999998   familia     visita_casual    0.451662
# 999997  499999   999999   familia       visita_rara    0.186973
# 999998  500000  1000000   familia       visita_rara         NaN
#
# [999999 rows x 5 columns]

# %%
ind_df = pd.read_csv('individuos_espec.csv', sep=';')

# %%
ind_df.head()
# Out:
#    name  idade estado_civil  qt_filhos  estuda  trabalha  pratica_esportes  \
# 0     1   44.0   divorciado        1.0     1.0       0.0               1.0
# 1     2   24.0       casado        0.0     0.0       0.0               1.0
# 2     3   35.0     solteiro        1.0     0.0       0.0               1.0
# 3     4   50.0       casado        1.0     1.0       1.0               0.0
# 4     5   30.0     solteiro        2.0     1.0       0.0               1.0
#
#   transporte_mais_utilizado        IMC
# 0                   publico  22.200956
# 1                   publico  25.378720
# 2                particular  19.952393
# 3                   publico  26.732053
# 4                   publico  15.295668

# %%
ind_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   name                       1000000 non-null  int64
#  1   idade                      904063 non-null   float64
#  2   estado_civil               949927 non-null   object
#  3   qt_filhos                  971133 non-null   float64
#  4   estuda                     959870 non-null   float64
#  5   trabalha                   993647 non-null   float64
#  6   pratica_esportes           850876 non-null   float64
#  7   transporte_mais_utilizado  956967 non-null   object
#  8   IMC                        886130 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 68.7+ MB

# %%
ind_df.describe(include='all').T
# Out:
#                                count unique       top    freq       mean  \
# name                       1000000.0    NaN       NaN     NaN   500000.5
# idade                       904063.0    NaN       NaN     NaN  30.008431
# estado_civil                  949927      4  solteiro  420637        NaN
# qt_filhos                   971133.0    NaN       NaN     NaN   0.928406
# estuda                      959870.0    NaN       NaN     NaN   0.442588
# trabalha                    993647.0    NaN       NaN     NaN   0.556739
# pratica_esportes            850876.0    NaN       NaN     NaN   0.599823
# transporte_mais_utilizado     956967      3   publico  574779        NaN
# IMC                         886130.0    NaN       NaN     NaN  22.472079
#
#                                      std       min        25%       50%  \
# name                       288675.278933       1.0  250000.75  500000.5
# idade                          10.951566       0.0       22.0      29.0
# estado_civil                         NaN       NaN        NaN       NaN
# qt_filhos                       0.997289       0.0        0.0       1.0
# estuda                          0.496693       0.0        0.0       0.0
# trabalha                        0.496771       0.0        0.0       1.0
# pratica_esportes                0.489934       0.0        0.0       1.0
# transporte_mais_utilizado            NaN       NaN        NaN       NaN
# IMC                             7.073692  4.852828  17.420851   21.4312
#
#                                  75%        max
# name                       750000.25  1000000.0
# idade                           37.0      124.0
# estado_civil                     NaN        NaN
# qt_filhos                        1.0        9.0
# estuda                           1.0        1.0
# trabalha                         1.0        1.0
# pratica_esportes                 1.0        1.0
# transporte_mais_utilizado        NaN        NaN
# IMC                        26.378197  89.158204

# %%
ind_df['estado_civil'].unique()
# Out:
# array(['divorciado', 'casado', 'solteiro', nan, 'viuvo'], dtype=object)

# %%
ind_df['transporte_mais_utilizado'].unique()
# Out:
# array(['publico', 'particular', 'taxi', nan], dtype=object)

# %%
df_raw = pd.merge(ind_df.rename(columns=lambda x: x + '_V2'),
                  conn_df, 
                  how='right',
                  left_on='name_V2', 
                  right_on='V2')
df_raw = pd.merge(ind_df.rename(columns=lambda x: x + '_V1'),
                  df_raw, 
                  how='right',
                  left_on='name_V1', 
                  right_on='V1')
df_raw = df_raw.drop(['V1', 'V2'], axis=1)
df_raw
# Out:
#         name_V1  idade_V1 estado_civil_V1  qt_filhos_V1  estuda_V1  \
# 0             1      44.0      divorciado           1.0        1.0
# 1             1      44.0      divorciado           1.0        1.0
# 2             2      24.0          casado           0.0        0.0
# 3             2      24.0          casado           0.0        0.0
# 4             3      35.0        solteiro           1.0        0.0
# ...         ...       ...             ...           ...        ...
# 999994   499998      23.0          casado           0.0        1.0
# 999995   499998      23.0          casado           0.0        1.0
# 999996   499999      26.0          casado           3.0        0.0
# 999997   499999      26.0          casado           3.0        0.0
# 999998   500000      12.0        solteiro           0.0        1.0
#
#         trabalha_V1  pratica_esportes_V1 transporte_mais_utilizado_V1  \
# 0               0.0                  1.0                      publico
# 1               0.0                  1.0                      publico
# 2               0.0                  1.0                      publico
# 3               0.0                  1.0                      publico
# 4               0.0                  1.0                   particular
# ...             ...                  ...                          ...
# 999994          1.0                  0.0                      publico
# 999995          1.0                  0.0                      publico
# 999996          0.0                  0.0                         taxi
# 999997          0.0                  0.0                         taxi
# 999998          0.0                  1.0                      publico
#
#            IMC_V1  name_V2  ...  estado_civil_V2 qt_filhos_V2  estuda_V2  \
# 0       22.200956        2  ...           casado          0.0        0.0
# 1       22.200956        3  ...         solteiro          1.0        0.0
# 2       25.378720        4  ...           casado          1.0        1.0
# 3       25.378720        5  ...         solteiro          2.0        1.0
# 4       19.952393        6  ...              NaN          1.0        0.0
# ...           ...      ...  ...              ...          ...        ...
# 999994  22.036885   999996  ...           casado          1.0        0.0
# 999995  22.036885   999997  ...           casado          1.0        0.0
# 999996  19.543889   999998  ...       divorciado          1.0        0.0
# 999997  19.543889   999999  ...           casado          0.0        1.0
# 999998  19.321093  1000000  ...         solteiro          0.0        0.0
#
#         trabalha_V2  pratica_esportes_V2  transporte_mais_utilizado_V2  \
# 0               0.0                  1.0                       publico
# 1               0.0                  1.0                    particular
# 2               1.0                  0.0                       publico
# 3               0.0                  1.0                       publico
# 4               1.0                  0.0                       publico
# ...             ...                  ...                           ...
# 999994          1.0                  1.0                       publico
# 999995          1.0                  1.0                    particular
# 999996          0.0                  1.0                       publico
# 999997          1.0                  1.0                       publico
# 999998          0.0                  0.0                           NaN
#
#            IMC_V2      grau       proximidade prob_V1_V2
# 0       25.378720  trabalho  visita_frequente   0.589462
# 1       19.952393  trabalho       visita_rara   0.708465
# 2       26.732053  trabalho     visita_casual        NaN
# 3       15.295668  trabalho       visita_rara   0.638842
# 4       20.412942    amigos        mora_junto        NaN
# ...           ...       ...               ...        ...
# 999994  17.556771  trabalho       visita_rara        NaN
# 999995  24.848402  trabalho       visita_rara        NaN
# 999996        NaN   familia     visita_casual   0.451662
# 999997  16.979569   familia       visita_rara   0.186973
# 999998  24.018825   familia       visita_rara        NaN
#
# [999999 rows x 21 columns]

# %%
def logit(p):
    return np.log(p / (1-p))

def logistic(y):
    ey = np.exp(y)
    return ey / (1+ey)

def cross_entropy_loss(y_true, y_pred):
    p, q = logistic(y_true), logistic(y_pred)
    return -(p*np.log(q) + (1-p)*np.log(1-q)).mean()

# %%
categorical_cols = ['estado_civil_V1', 'estado_civil_V2',
                    'transporte_mais_utilizado_V1', 'transporte_mais_utilizado_V2',
                    'grau', 'proximidade']

boolean_cols = ['estuda_V1', 'trabalha_V1', 'pratica_esportes_V1',
                'estuda_V2', 'trabalha_V2', 'pratica_esportes_V2']

numerical_cols = ['idade_V1', 'qt_filhos_V1', 'IMC_V1',
                  'idade_V2', 'qt_filhos_V2', 'IMC_V2']

cols_to_drop = ['name_V1', 'name_V2', 'prob_V1_V2']

# %%
df_bl = df_raw.copy(deep=True)

df_bl['prob_V1_V2'].fillna(df_bl['prob_V1_V2'].median(), inplace=True)

# %%
X_bl = df_bl.drop(cols_to_drop, axis=1)
y_bl = df_bl['prob_V1_V2']

X_bl_train_, X_bl_test_, y_bl_train, y_bl_test = train_test_split(X_bl,
                                                                  logit(y_bl),
                                                                  test_size=0.4,
                                                                  random_state=42)

# %%
X_bl_train, X_bl_test = X_bl_train_.copy(deep=True), X_bl_test_.copy(deep=True)

mode_imp = SimpleImputer(strategy='most_frequent')
mean_imp = SimpleImputer(strategy='mean')
median_imp = SimpleImputer(strategy='median')

X_bl_train[categorical_cols] = mode_imp.fit_transform(X_bl_train_[categorical_cols])
X_bl_train[boolean_cols] = mean_imp.fit_transform(X_bl_train_[boolean_cols])
X_bl_train[numerical_cols] = median_imp.fit_transform(X_bl_train_[numerical_cols])

X_bl_test[categorical_cols] = mode_imp.transform(X_bl_test_[categorical_cols])
X_bl_test[boolean_cols] = mean_imp.transform(X_bl_test_[boolean_cols])
X_bl_test[numerical_cols] = median_imp.transform(X_bl_test_[numerical_cols])

# %%
# prox_ord = ['visita_rara', 'visita_casual', 'visita_frequente', 'mora_junto']
# transp_ord = ['particular', 'taxi', 'publico']
# ord_enc = OrdinalEncoder(categories=[transp_ord, transp_ord, prox_ord])

# X_bl_train[ordinal_cat_cols] = ord_enc.fit_transform(X_bl_train[ordinal_cat_cols])
# X_bl_test[ordinal_cat_cols] = ord_enc.transform(X_bl_test[ordinal_cat_cols])

# %%
one_enc = OneHotEncoder(drop='first', sparse=False)
one_enc.fit(X_bl_train[categorical_cols])

one_hot_cols = one_enc.get_feature_names(categorical_cols)

X_bl_train[one_hot_cols] = one_enc.transform(X_bl_train[categorical_cols])
X_bl_train.drop(categorical_cols, axis=1, inplace=True)

X_bl_test[one_hot_cols] = one_enc.transform(X_bl_test[categorical_cols])
X_bl_test.drop(categorical_cols, axis=1, inplace=True)

# %%
bl_model = LinearRegression().fit(X_bl_train, y_bl_train)

# %%
train_loss = cross_entropy_loss(y_bl_train, bl_model.predict(X_bl_train))
test_loss = cross_entropy_loss(y_bl_test, bl_model.predict(X_bl_test))

print('baseline train loss:', train_loss)
print('baseline test loss:', test_loss)
# Out:
# baseline train loss: 0.684272325646911
# baseline test loss: 0.6842074405738243

# %%
df_1 = df_raw.copy(deep=True).sample(frac=0.1, random_state=42)

# %%
df_1
# Out:
#         name_V1  idade_V1 estado_civil_V1  qt_filhos_V1  estuda_V1  \
# 987230   493616      48.0        solteiro           0.0        1.0
# 79954     39978      33.0          casado           1.0        0.0
# 567130   283566      24.0        solteiro           1.0        0.0
# 500891   250446       NaN        solteiro           0.0        1.0
# 55399     27700      31.0        solteiro           0.0        NaN
# ...         ...       ...             ...           ...        ...
# 395942   197972      25.0      divorciado           2.0        0.0
# 417771   208886      24.0        solteiro           1.0        0.0
# 713259   356630      28.0        solteiro           2.0        1.0
# 794021   397011      36.0          casado           0.0        0.0
# 573083   286542      21.0           viuvo           1.0        0.0
#
#         trabalha_V1  pratica_esportes_V1 transporte_mais_utilizado_V1  \
# 987230          0.0                  NaN                      publico
# 79954           0.0                  1.0                   particular
# 567130          0.0                  1.0                   particular
# 500891          0.0                  1.0                   particular
# 55399           1.0                  1.0                   particular
# ...             ...                  ...                          ...
# 395942          1.0                  NaN                      publico
# 417771          1.0                  1.0                         taxi
# 713259          1.0                  1.0                   particular
# 794021          1.0                  0.0                   particular
# 573083          1.0                  1.0                   particular
#
#            IMC_V1  name_V2  ...  estado_civil_V2 qt_filhos_V2  estuda_V2  \
# 987230        NaN   987232  ...       divorciado          0.0        1.0
# 79954   36.497011    79956  ...            viuvo          1.0        0.0
# 567130  21.733414   567132  ...       divorciado          1.0        0.0
# 500891  11.278218   500893  ...       divorciado          4.0        0.0
# 55399   13.226648    55401  ...         solteiro          1.0        1.0
# ...           ...      ...  ...              ...          ...        ...
# 395942  16.327677   395944  ...           casado          1.0        0.0
# 417771  19.201943   417773  ...         solteiro          1.0        1.0
# 713259  15.976760   713261  ...       divorciado          NaN        1.0
# 794021  18.807305   794023  ...           casado          1.0        0.0
# 573083  16.524598   573085  ...       divorciado          1.0        0.0
#
#         trabalha_V2  pratica_esportes_V2  transporte_mais_utilizado_V2  \
# 987230          1.0                  0.0                       publico
# 79954           0.0                  1.0                       publico
# 567130          0.0                  1.0                       publico
# 500891          1.0                  0.0                       publico
# 55399           1.0                  0.0                       publico
# ...             ...                  ...                           ...
# 395942          0.0                  1.0                    particular
# 417771          1.0                  1.0                    particular
# 713259          1.0                  1.0                    particular
# 794021          0.0                  1.0                    particular
# 573083          1.0                  0.0                       publico
#
#            IMC_V2      grau       proximidade prob_V1_V2
# 987230  23.629884   familia  visita_frequente        NaN
# 79954   15.739333    amigos  visita_frequente        NaN
# 567130  37.438250  trabalho     visita_casual   0.470959
# 500891  12.541784   familia     visita_casual   0.639066
# 55399   22.814826  trabalho       visita_rara        NaN
# ...           ...       ...               ...        ...
# 395942        NaN   familia       visita_rara   0.297126
# 417771  20.485265   familia       visita_rara   0.301117
# 713259  17.146773    amigos       visita_rara   0.400940
# 794021  25.896600    amigos       visita_rara        NaN
# 573083  33.976581    amigos       visita_rara   0.358416
#
# [100000 rows x 21 columns]

# %%
X_1 = df_1.drop(cols_to_drop, axis=1)
y_1 = df_1['prob_V1_V2']

X_1_train_, X_1_test_, y_1_train, y_1_test = train_test_split(X_1,
                                                              logit(y_1),
                                                              test_size=0.2,
                                                              random_state=42)

# %%
X_1_train, X_1_test = X_1_train_.copy(deep=True), X_1_test_.copy(deep=True)

mode_imp = SimpleImputer(strategy='most_frequent')
mean_imp = SimpleImputer(strategy='mean')
median_imp = SimpleImputer(strategy='median')

X_1_train[categorical_cols] = mode_imp.fit_transform(X_1_train_[categorical_cols])
X_1_train[boolean_cols] = mean_imp.fit_transform(X_1_train_[boolean_cols])
X_1_train[numerical_cols] = median_imp.fit_transform(X_1_train_[numerical_cols])

X_1_test[categorical_cols] = mode_imp.transform(X_1_test_[categorical_cols])
X_1_test[boolean_cols] = mean_imp.transform(X_1_test_[boolean_cols])
X_1_test[numerical_cols] = median_imp.transform(X_1_test_[numerical_cols])

# %%
one_enc = OneHotEncoder(drop='first', sparse=False)
one_enc.fit(X_1_train[categorical_cols])

one_hot_cols = one_enc.get_feature_names(categorical_cols)

X_1_train[one_hot_cols] = one_enc.transform(X_1_train[categorical_cols])
X_1_train.drop(categorical_cols, axis=1, inplace=True)

X_1_test[one_hot_cols] = one_enc.transform(X_1_test[categorical_cols])
X_1_test.drop(categorical_cols, axis=1, inplace=True)

# %%
X_1_train['is_train'], X_1_test['is_train'] = True, False

X_1 = X_1_train.append(X_1_test)
y_1 = y_1_train.append(y_1_test)

# %%
scaler = MinMaxScaler()
pca = PCA(n_components=0.9, random_state=42)

X_1_ = pca.fit_transform(scaler.fit_transform(X_1.drop('is_train', axis=1)))
pca_comps = [f'pc_{n+1}' for n in range(X_1_.shape[1])]
X_1_ = pd.DataFrame(scaler.fit_transform(X_1_), index=X_1.index, columns=pca_comps)

pd.Series(pca.explained_variance_ratio_, index=pca_comps).cumsum()

# %%
X_1_ = X_1_.loc[:, :'pc_16']
df_1_ = pd.concat([X_1_, y_1.rename('logit_prob_V1_V2')], axis=1)

df_1_
# Out:
#         idade_V1  qt_filhos_V1  estuda_V1  trabalha_V1  pratica_esportes_V1  \
# 868974  0.435644      0.000000        1.0          1.0                  1.0
# 411690  0.267327      0.000000        0.0          1.0                  1.0
# 616280  0.287129      0.142857        0.0          0.0                  1.0
# 267494  0.356436      0.000000        1.0          1.0                  1.0
# 420509  0.287129      0.428571        0.0          1.0                  1.0
# ...          ...           ...        ...          ...                  ...
# 302463  0.297030      0.000000        1.0          0.0                  0.0
# 666057  0.415842      0.000000        0.0          1.0                  1.0
# 252899  0.326733      0.142857        0.0          0.0                  1.0
# 612256  0.405941      0.142857        1.0          1.0                  0.0
# 736004  0.326733      0.142857        1.0          1.0                  0.0
#
#           IMC_V1  idade_V2  qt_filhos_V2  estuda_V2  trabalha_V2  ...  \
# 868974  0.070383  0.329545      0.285714        1.0          1.0  ...
# 411690  0.221980  0.397727      0.142857        1.0          0.0  ...
# 616280  0.193617  0.215909      0.000000        0.0          1.0  ...
# 267494  0.112285  0.181818      0.142857        1.0          1.0  ...
# 420509  0.152509  0.306818      0.000000        1.0          1.0  ...
# ...          ...       ...           ...        ...          ...  ...
# 302463  0.281490  0.125000      0.000000        1.0          0.0  ...
# 666057  0.059846  0.306818      0.000000        1.0          0.0  ...
# 252899  0.126751  0.215909      0.285714        0.0          0.0  ...
# 612256  0.085908  0.272727      0.142857        0.0          0.0  ...
# 736004  0.193617  0.500000      0.142857        0.0          0.0  ...
#
#         transporte_mais_utilizado_V1_publico  \
# 868974                                   1.0
# 411690                                   1.0
# 616280                                   0.0
# 267494                                   1.0
# 420509                                   0.0
# ...                                      ...
# 302463                                   0.0
# 666057                                   0.0
# 252899                                   0.0
# 612256                                   1.0
# 736004                                   0.0
#
#         transporte_mais_utilizado_V1_taxi  \
# 868974                                0.0
# 411690                                0.0
# 616280                                0.0
# 267494                                0.0
# 420509                                1.0
# ...                                   ...
# 302463                                0.0
# 666057                                0.0
# 252899                                0.0
# 612256                                0.0
# 736004                                0.0
#
#         transporte_mais_utilizado_V2_publico  \
# 868974                                   1.0
# 411690                                   1.0
# 616280                                   1.0
# 267494                                   1.0
# 420509                                   0.0
# ...                                      ...
# 302463                                   1.0
# 666057                                   0.0
# 252899                                   1.0
# 612256                                   1.0
# 736004                                   1.0
#
#         transporte_mais_utilizado_V2_taxi  grau_familia  grau_trabalho  \
# 868974                                0.0           0.0            1.0
# 411690                                0.0           0.0            0.0
# 616280                                0.0           1.0            0.0
# 267494                                0.0           0.0            1.0
# 420509                                0.0           0.0            1.0
# ...                                   ...           ...            ...
# 302463                                0.0           0.0            0.0
# 666057                                0.0           0.0            0.0
# 252899                                0.0           0.0            0.0
# 612256                                0.0           0.0            1.0
# 736004                                0.0           0.0            0.0
#
#         proximidade_visita_casual  proximidade_visita_frequente  \
# 868974                        0.0                           1.0
# 411690                        1.0                           0.0
# 616280                        1.0                           0.0
# 267494                        0.0                           0.0
# 420509                        0.0                           1.0
# ...                           ...                           ...
# 302463                        0.0                           1.0
# 666057                        1.0                           0.0
# 252899                        1.0                           0.0
# 612256                        0.0                           1.0
# 736004                        0.0                           0.0
#
#         proximidade_visita_rara  logit_prob_V1_V2
# 868974                      0.0               NaN
# 411690                      0.0          0.321389
# 616280                      0.0          1.234459
# 267494                      1.0         -0.642401
# 420509                      0.0               NaN
# ...                         ...               ...
# 302463                      0.0               NaN
# 666057                      0.0         -0.383085
# 252899                      0.0               NaN
# 612256                      0.0         -0.559819
# 736004                      0.0               NaN
#
# [100000 rows x 28 columns]

# %%
df_1_.describe().T
# Out:
#                                          count      mean       std       min  \
# idade_V1                              100000.0  0.276455  0.103680  0.000000
# qt_filhos_V1                          100000.0  0.133207  0.140252  0.000000
# estuda_V1                             100000.0  0.445127  0.487042  0.000000
# trabalha_V1                           100000.0  0.558133  0.495051  0.000000
# pratica_esportes_V1                   100000.0  0.598143  0.451936  0.000000
# IMC_V1                                100000.0  0.205185  0.082055  0.000000
# idade_V2                              100000.0  0.317138  0.118605  0.000000
# qt_filhos_V2                          100000.0  0.133146  0.140926  0.000000
# estuda_V2                             100000.0  0.442484  0.486820  0.000000
# trabalha_V2                           100000.0  0.555347  0.495363  0.000000
# pratica_esportes_V2                   100000.0  0.601237  0.452125  0.000000
# IMC_V2                                100000.0  0.239116  0.095489  0.000000
# estado_civil_V1_divorciado            100000.0  0.174600  0.379627  0.000000
# estado_civil_V1_solteiro              100000.0  0.468680  0.499021  0.000000
# estado_civil_V1_viuvo                 100000.0  0.087870  0.283107  0.000000
# estado_civil_V2_divorciado            100000.0  0.175350  0.380268  0.000000
# estado_civil_V2_solteiro              100000.0  0.469730  0.499085  0.000000
# estado_civil_V2_viuvo                 100000.0  0.088120  0.283471  0.000000
# transporte_mais_utilizado_V1_publico  100000.0  0.617290  0.486051  0.000000
# transporte_mais_utilizado_V1_taxi     100000.0  0.047230  0.212132  0.000000
# transporte_mais_utilizado_V2_publico  100000.0  0.620760  0.485200  0.000000
# transporte_mais_utilizado_V2_taxi     100000.0  0.048110  0.214000  0.000000
# grau_familia                          100000.0  0.333550  0.471483  0.000000
# grau_trabalho                         100000.0  0.332140  0.470983  0.000000
# proximidade_visita_casual             100000.0  0.301880  0.459076  0.000000
# proximidade_visita_frequente          100000.0  0.199850  0.399889  0.000000
# proximidade_visita_rara               100000.0  0.398450  0.489581  0.000000
# logit_prob_V1_V2                       49922.0 -0.072044  0.782690 -2.510617
#
#                                            25%       50%       75%       max
# idade_V1                              0.207921  0.267327  0.336634  1.000000
# qt_filhos_V1                          0.000000  0.142857  0.142857  1.000000
# estuda_V1                             0.000000  0.000000  1.000000  1.000000
# trabalha_V1                           0.000000  1.000000  1.000000  1.000000
# pratica_esportes_V1                   0.000000  1.000000  1.000000  1.000000
# IMC_V1                                0.151108  0.193617  0.245065  1.000000
# idade_V2                              0.238636  0.306818  0.386364  1.000000
# qt_filhos_V2                          0.000000  0.142857  0.142857  1.000000
# estuda_V2                             0.000000  0.000000  1.000000  1.000000
# trabalha_V2                           0.000000  1.000000  1.000000  1.000000
# pratica_esportes_V2                   0.000000  1.000000  1.000000  1.000000
# IMC_V2                                0.175877  0.225974  0.286060  1.000000
# estado_civil_V1_divorciado            0.000000  0.000000  0.000000  1.000000
# estado_civil_V1_solteiro              0.000000  0.000000  1.000000  1.000000
# estado_civil_V1_viuvo                 0.000000  0.000000  0.000000  1.000000
# estado_civil_V2_divorciado            0.000000  0.000000  0.000000  1.000000
# estado_civil_V2_solteiro              0.000000  0.000000  1.000000  1.000000
# estado_civil_V2_viuvo                 0.000000  0.000000  0.000000  1.000000
# transporte_mais_utilizado_V1_publico  0.000000  1.000000  1.000000  1.000000
# transporte_mais_utilizado_V1_taxi     0.000000  0.000000  0.000000  1.000000
# transporte_mais_utilizado_V2_publico  0.000000  1.000000  1.000000  1.000000
# transporte_mais_utilizado_V2_taxi     0.000000  0.000000  0.000000  1.000000
# grau_familia                          0.000000  0.000000  1.000000  1.000000
# grau_trabalho                         0.000000  0.000000  1.000000  1.000000
# proximidade_visita_casual             0.000000  0.000000  1.000000  1.000000
# proximidade_visita_frequente          0.000000  0.000000  0.000000  1.000000
# proximidade_visita_rara               0.000000  0.000000  1.000000  1.000000
# logit_prob_V1_V2                     -0.612558 -0.056881  0.478273  2.781737

# %%
knn_imp = KNNImputer(weights='distance')

y_1_ = knn_imp.fit_transform(df_1_)[:, -1]

# %%
df_1 = pd.concat([X_1, pd.Series(y_1_, index=X_1.index, name='logit_prob_V1_V2')], axis=1)

df_1
# Out:
#         idade_V1  qt_filhos_V1  estuda_V1  trabalha_V1  pratica_esportes_V1  \
# 868974      46.0           0.0        1.0          1.0                  1.0
# 411690      29.0           0.0        0.0          1.0                  1.0
# 616280      31.0           1.0        0.0          0.0                  1.0
# 267494      38.0           0.0        1.0          1.0                  1.0
# 420509      31.0           3.0        0.0          1.0                  1.0
# ...          ...           ...        ...          ...                  ...
# 302463      32.0           0.0        1.0          0.0                  0.0
# 666057      44.0           0.0        0.0          1.0                  1.0
# 252899      35.0           1.0        0.0          0.0                  1.0
# 612256      43.0           1.0        1.0          1.0                  0.0
# 736004      35.0           1.0        1.0          1.0                  0.0
#
#            IMC_V1  idade_V2  qt_filhos_V2  estuda_V2  trabalha_V2  ...  \
# 868974  11.411365      31.0           2.0        1.0          1.0  ...
# 411690  23.690345      37.0           1.0        1.0          0.0  ...
# 616280  21.393032      21.0           0.0        0.0          1.0  ...
# 267494  14.805366      18.0           1.0        1.0          1.0  ...
# 420509  18.063386      29.0           0.0        1.0          1.0  ...
# ...           ...       ...           ...        ...          ...  ...
# 302463  28.510499      13.0           0.0        1.0          0.0  ...
# 666057  10.557943      29.0           0.0        1.0          0.0  ...
# 252899  15.977035      21.0           2.0        0.0          0.0  ...
# 612256  12.668878      26.0           1.0        0.0          0.0  ...
# 736004  21.393032      46.0           1.0        0.0          0.0  ...
#
#         transporte_mais_utilizado_V1_taxi  \
# 868974                                0.0
# 411690                                0.0
# 616280                                0.0
# 267494                                0.0
# 420509                                1.0
# ...                                   ...
# 302463                                0.0
# 666057                                0.0
# 252899                                0.0
# 612256                                0.0
# 736004                                0.0
#
#         transporte_mais_utilizado_V2_publico  \
# 868974                                   1.0
# 411690                                   1.0
# 616280                                   1.0
# 267494                                   1.0
# 420509                                   0.0
# ...                                      ...
# 302463                                   1.0
# 666057                                   0.0
# 252899                                   1.0
# 612256                                   1.0
# 736004                                   1.0
#
#         transporte_mais_utilizado_V2_taxi  grau_familia  grau_trabalho  \
# 868974                                0.0           0.0            1.0
# 411690                                0.0           0.0            0.0
# 616280                                0.0           1.0            0.0
# 267494                                0.0           0.0            1.0
# 420509                                0.0           0.0            1.0
# ...                                   ...           ...            ...
# 302463                                0.0           0.0            0.0
# 666057                                0.0           0.0            0.0
# 252899                                0.0           0.0            0.0
# 612256                                0.0           0.0            1.0
# 736004                                0.0           0.0            0.0
#
#         proximidade_visita_casual  proximidade_visita_frequente  \
# 868974                        0.0                           1.0
# 411690                        1.0                           0.0
# 616280                        1.0                           0.0
# 267494                        0.0                           0.0
# 420509                        0.0                           1.0
# ...                           ...                           ...
# 302463                        0.0                           1.0
# 666057                        1.0                           0.0
# 252899                        1.0                           0.0
# 612256                        0.0                           1.0
# 736004                        0.0                           0.0
#
#         proximidade_visita_rara  is_train  logit_prob_V1_V2
# 868974                      0.0      True          0.082141
# 411690                      0.0      True          0.321389
# 616280                      0.0      True          1.234459
# 267494                      1.0      True         -0.642401
# 420509                      0.0      True          0.444466
# ...                         ...       ...               ...
# 302463                      0.0     False          1.120099
# 666057                      0.0     False         -0.383085
# 252899                      0.0     False         -0.045296
# 612256                      0.0     False         -0.559819
# 736004                      0.0     False         -1.711550
#
# [100000 rows x 29 columns]

# %%
df_1_train = df_1.loc[df_1['is_train']].drop('is_train', axis=1)
df_1_test = df_1.loc[~df_1['is_train']].drop('is_train', axis=1)

X_1_train = df_1_train.drop('logit_prob_V1_V2', axis=1)
y_1_train = df_1_train['logit_prob_V1_V2']
X_1_test = df_1_test.drop('logit_prob_V1_V2', axis=1)
y_1_test = df_1_test['logit_prob_V1_V2']

# %%
lr_1_model = LinearRegression().fit(X_1_train, y_1_train)

# %%
train_loss = cross_entropy_loss(y_1_train, lr_1_model.predict(X_1_train))
test_loss = cross_entropy_loss(y_1_test, lr_1_model.predict(X_1_test))

print('lr_1 train loss:', train_loss)
print('lr_1 test loss:', test_loss)
# Out:
# lr_1 train loss: 0.6598879658096841
# lr_1 test loss: 0.6601786703950473

# %%
df_2 = df_raw.copy(deep=True)

# %%
X_2 = df_2.drop(cols_to_drop, axis=1)
y_2 = df_2['prob_V1_V2']

X_2_train_, X_2_test_, y_2_train, y_2_test = train_test_split(X_2,
                                                              logit(y_2),
                                                              test_size=0.4,
                                                              random_state=42)

# %%
X_2_train_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599999 entries, 333136 to 121958
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   idade_V1                      542379 non-null  float64
#  1   estado_civil_V1               569824 non-null  object
#  2   qt_filhos_V1                  582618 non-null  float64
#  3   estuda_V1                     576154 non-null  float64
#  4   trabalha_V1                   596134 non-null  float64
#  5   pratica_esportes_V1           510554 non-null  float64
#  6   transporte_mais_utilizado_V1  574015 non-null  object
#  7   IMC_V1                        531809 non-null  float64
#  8   idade_V2                      542260 non-null  float64
#  9   estado_civil_V2               570197 non-null  object
#  10  qt_filhos_V2                  582612 non-null  float64
#  11  estuda_V2                     575694 non-null  float64
#  12  trabalha_V2                   596174 non-null  float64
#  13  pratica_esportes_V2           510517 non-null  float64
#  14  transporte_mais_utilizado_V2  574229 non-null  object
#  15  IMC_V2                        531543 non-null  float64
#  16  grau                          599999 non-null  object
#  17  proximidade                   599999 non-null  object
# dtypes: float64(12), object(6)
# memory usage: 87.0+ MB

# %%
names_1 = df_2.loc[X_2_train_.index, 'name_V1'].unique()
names_2 = df_2.loc[X_2_train_.index, 'name_V2'].unique()
names = np.append(names_1, names_2)

# %%
ind_df_2 = ind_df.loc[ind_df['name'].isin(names)]
ind_df_2
# Out:
#            name  idade estado_civil  qt_filhos  estuda  trabalha  \
# 0             1   44.0   divorciado        1.0     1.0       0.0
# 1             2   24.0       casado        0.0     0.0       0.0
# 2             3   35.0     solteiro        1.0     0.0       0.0
# 3             4   50.0       casado        1.0     1.0       1.0
# 4             5   30.0     solteiro        2.0     1.0       0.0
# ...         ...    ...          ...        ...     ...       ...
# 999994   999995   33.0       casado        0.0     0.0       0.0
# 999995   999996   34.0       casado        1.0     0.0       1.0
# 999996   999997   40.0       casado        1.0     0.0       1.0
# 999998   999999   33.0       casado        0.0     1.0       1.0
# 999999  1000000   22.0     solteiro        0.0     0.0       0.0
#
#         pratica_esportes transporte_mais_utilizado        IMC
# 0                    1.0                   publico  22.200956
# 1                    1.0                   publico  25.378720
# 2                    1.0                particular  19.952393
# 3                    0.0                   publico  26.732053
# 4                    1.0                   publico  15.295668
# ...                  ...                       ...        ...
# 999994               NaN                particular  16.982246
# 999995               1.0                   publico  17.556771
# 999996               1.0                particular  24.848402
# 999998               1.0                   publico  16.979569
# 999999               0.0                       NaN  24.018825
#
# [767902 rows x 9 columns]

# %%
ind_df_2.isna().mean().sort_values()
# Out:
# name                         0.000000
# trabalha                     0.006343
# qt_filhos                    0.028885
# estuda                       0.040348
# transporte_mais_utilizado    0.043163
# estado_civil                 0.050010
# idade                        0.096145
# IMC                          0.114082
# pratica_esportes             0.149260
# dtype: float64

# %%
df_imp = ind_df_2.drop('name', axis=1)
df_imp = df_imp.dropna(subset=df_imp.columns.drop('trabalha'), axis=0)

df_imp = pd.get_dummies(df_imp.dropna(subset=['trabalha'], axis=0), drop_first=True)
X_train_, X_test_, y_train, y_test = train_test_split(df_imp.drop('trabalha', axis=1),
                                                      df_imp_train['trabalha'],
                                                      test_size=0.4,
                                                      random_state=42)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_)
X_test = scaler.transform(X_test_)

lr = LogisticRegressionCV(penalty='elasticnet',
                          solver='saga',
                          n_jobs=-1,
                          random_state=42,
                          l1_ratios=[1])
lr.fit(X_train, y_train);

# %%
pd.Series(lr.coef_.squeeze(), index=X_train_.columns)
# Out:
# idade                                0.484991
# qt_filhos                            0.000000
# estuda                              -0.276310
# pratica_esportes                     0.000000
# IMC                                  0.000000
# estado_civil_divorciado              0.000000
# estado_civil_solteiro               -0.271118
# estado_civil_viuvo                   0.000000
# transporte_mais_utilizado_publico    0.000000
# transporte_mais_utilizado_taxi       0.000000
# dtype: float64

# %%
train_score = lr.score(X_train, y_train)
test_score = lr.score(X_test, y_test)

print('train score:', train_score)
print('test score:', test_score)
# Out:
# train score: 0.6012163829449032
# test score: 0.6026704361598856

# %%
df_imp_isna = df_imp.loc[df_imp['trabalha'].isna()]
X_isna = pd.get_dummies(df_imp_test.drop('trabalha', axis=1), drop_first=True)

# %%
ind_df_2.loc[X_isna.index, 'trabalha'] = lr.predict(X_isna)
# Out:
# C:\Users\jeffersonlc\Anaconda3\envs\case_neoway\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
ind_df_2.describe().T
# Out:
#                      count           mean            std       min  \
# name              767902.0  445344.091246  283478.893379  1.000000
# idade             694072.0      29.997822      10.947440  0.000000
# qt_filhos         745721.0       0.927297       0.996882  0.000000
# estuda            736919.0       0.442560       0.496690  0.000000
# trabalha          765825.0       0.558269       0.496593  0.000000
# pratica_esportes  653285.0       0.600055       0.489887  0.000000
# IMC               680298.0      22.470468       7.071299  4.852828
#
#                             25%            50%            75%             max
# name              205125.250000  410248.500000  680133.750000  1000000.000000
# idade                 22.000000      29.000000      37.000000      124.000000
# qt_filhos              0.000000       1.000000       1.000000        8.000000
# estuda                 0.000000       0.000000       1.000000        1.000000
# trabalha               0.000000       1.000000       1.000000        1.000000
# pratica_esportes       0.000000       1.000000       1.000000        1.000000
# IMC                   17.420319      21.428833      26.375108       89.158204

# %%
ind_df_2.loc[X_isna.index]
# Out:
#           name  idade estado_civil  qt_filhos  estuda  trabalha  \
# 144        145   38.0       casado        1.0     0.0       1.0
# 146        147   28.0       casado        0.0     0.0       1.0
# 320        321   25.0     solteiro        1.0     0.0       1.0
# 352        353   27.0   divorciado        0.0     0.0       1.0
# 400        401   40.0   divorciado        1.0     1.0       1.0
# ...        ...    ...          ...        ...     ...       ...
# 996036  996037   18.0       casado        0.0     0.0       1.0
# 996116  996117   30.0   divorciado        3.0     0.0       1.0
# 997057  997058   40.0       casado        2.0     0.0       1.0
# 998144  998145   18.0        viuvo        0.0     0.0       1.0
# 999749  999750   24.0     solteiro        1.0     1.0       1.0
#
#         pratica_esportes transporte_mais_utilizado        IMC
# 144                  1.0                particular  17.358752
# 146                  0.0                   publico  21.983078
# 320                  0.0                   publico  17.515253
# 352                  1.0                   publico  18.204883
# 400                  1.0                   publico  26.186201
# ...                  ...                       ...        ...
# 996036               1.0                particular  21.565478
# 996116               1.0                particular  18.328365
# 997057               0.0                   publico  13.079058
# 998144               0.0                particular  21.014601
# 999749               0.0                   publico  16.356146
#
# [2794 rows x 9 columns]
